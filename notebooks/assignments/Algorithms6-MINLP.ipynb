# %% [markdown]
# # Algorithms Homework 6: MINLP algorithms in practice
#
# **Assignment overview.** Notebook [](../8/MINLP-Algorithms.ipynb) implemented branch and bound, outer
# approximation and generalized Benders decomposition by hand, on problems small enough to watch. This
# assignment does the opposite: you drive a *production* MINLP solver — Pyomo's **MindtPy** — on a problem
# too big to watch, and use the theory from the handout to explain what comes back.
#
# You will not write an algorithm here. You will write **one line**, over and over, with one option changed
# each time:
#
# ```python
# results = pyo.SolverFactory("mindtpy").solve(
#     m, strategy="OA", mip_solver="appsi_highs", nlp_solver="ipopt"
# )
# ```
#
# and then account for the iteration counts, the run times, and — in two cases — the *wrong answers*.

# %% [markdown]
# ## Tips and tricks
#
# * **MindtPy's `strategy=` argument selects the algorithm.** `"OA"` is outer approximation (handout §4),
#   `"ECP"` is the extended cutting plane method, `"GOA"` is global outer approximation, and `"FP"` is the
#   feasibility pump.
# * **MindtPy is a *meta*-solver.** It has no numerics of its own: it calls an MILP solver for the master
#   problems (`mip_solver=`) and an NLP solver for the subproblems (`nlp_solver=`). Both must be named.
# * **Check the termination condition every single time.** This is not boilerplate in this assignment — it
#   is one of the graded findings. At least one strategy below returns an answer *and* a termination
#   condition that is not `optimal`, and a student who skips the check will report a number that is 10 %
#   off as if it were the optimum.
# * `results.solver.iterations` holds the number of major iterations for most strategies. Use
#   `getattr(results.solver, "iterations", None)` so a missing field does not crash your loop.
# * MindtPy is chatty. Wrap the solve in the `quiet()` helper provided below when you want a clean table.
# * Wall time is measured with `time.perf_counter()`, and it is noisy at this problem size. Report it to
#   two decimals, do not over-interpret differences under about 0.5 s, and re-run before you claim anything
#   about speed.
#
# **Reference:** the [MindtPy documentation](https://pyomo.readthedocs.io/en/stable/explanation/solvers/mindtpy.html),
# and Biegler, Grossmann & Westerberg (1997) Appendix A, §A.3.2 and §A.3.4.

# %%
# This code cell installs packages on Colab

import sys

if "google.colab" in sys.modules:
    # !wget "https://raw.githubusercontent.com/ndcbe/optimization/main/notebooks/helper.py"
    import helper

    helper.easy_install()
else:
    sys.path.insert(0, "../")
    import helper

helper.set_plotting_style()

# %%
import contextlib
import io
import time

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pyomo.environ as pyo

rng = np.random.default_rng(seed=0)


@contextlib.contextmanager
def quiet():
    """Swallow a solver's chatter so a loop can print a clean table."""
    buf = io.StringIO()
    with contextlib.redirect_stdout(buf):
        yield buf

# %% [markdown]
# ## Part 0. The model
#
# A whole-building insulation retrofit. Four wall assemblies — three walls and a roof — are to be insulated
# from a catalogue of eight materials. This is the notebook's single-wall problem with three things added,
# each of which makes the binary structure genuinely hard:
#
# * **Per-assembly layer choice.** $y_{w,n} = 1$ if material $n$ is installed on assembly $w$, with
#   thickness $x_{w,n} \le t^{\max}_n y_{w,n}$.
# * **A stocking decision.** $z_n = 1$ if material $n$ is used *anywhere*. Each stocked material costs a
#   fixed crew/logistics charge, so the optimizer is pushed toward using few materials on many walls —
#   the constraint $y_{w,n} \le z_n$ couples the assemblies together.
# * **A capital budget.** Total installed cost is capped, which is what makes this a constrained
#   combinatorial problem rather than four independent ones.
#
# $$
# \begin{aligned}
# \min_{x,y,z} \quad
#   & \sum_{w} A_w \left[ \frac{\alpha}{R_w} + \beta \sum_n \left( a_n y_{w,n} + b_n x_{w,n} \right) \right]
#     + \beta \, \kappa \sum_n z_n \\
# \text{s.t.} \quad
#   & R_w = R_{0,w} + \sum_n \frac{x_{w,n}}{k_n} && \forall w \\
#   & x_{w,n} \le t^{\max}_n \, y_{w,n},
#     \qquad y_{w,n} \le z_n && \forall w, n \\
#   & \sum_n x_{w,n} \le t^{\max}_w && \forall w \\
#   & \sum_{w} A_w \sum_n \left( a_n y_{w,n} + b_n x_{w,n} \right) + \kappa \sum_n z_n \le \mathcal{B} \\
#   & x \ge 0, \qquad y, z \in \{0,1\}
# \end{aligned}
# $$
#
# The objective is **convex** for fixed $y$: $\alpha/R_w$ is convex in $x$ because $R_w$ is affine and
# positive, and everything else is linear. Every constraint is linear. So this is a convex MINLP, and outer
# approximation and generalized Benders both apply with their guarantees intact. Part 4 breaks that on
# purpose.
#
# There are $4 \times 8 + 8 = 40$ binary variables here, so complete enumeration would need $2^{40} \approx
# 10^{12}$ NLP solves.

# %%
# k: thermal conductivity [W/m/K]; a: fixed installation cost [$/m^2];
# b: installed material cost [$/m^3]; tmax: largest available thickness [m]
materials = pd.DataFrame(
    {
        "Fiberglass batt": {"k": 0.040, "a": 4.0, "b": 60.0, "tmax": 0.06},
        "Mineral wool": {"k": 0.030, "a": 5.0, "b": 150.0, "tmax": 0.06},
        "Rigid foam (low R)": {"k": 0.030, "a": 8.0, "b": 120.0, "tmax": 0.05},
        "Rigid foam (high R)": {"k": 0.015, "a": 8.0, "b": 180.0, "tmax": 0.05},
        "Aerogel blanket": {"k": 0.013, "a": 12.0, "b": 900.0, "tmax": 0.02},
        "Cellulose fill": {"k": 0.038, "a": 3.0, "b": 45.0, "tmax": 0.08},
        "Polyiso board": {"k": 0.022, "a": 7.0, "b": 160.0, "tmax": 0.05},
        "Vacuum panel": {"k": 0.007, "a": 25.0, "b": 2500.0, "tmax": 0.015},
    }
).T

# area [m^2]; R0: resistance of the structural elements [m^2 K / W];
# tmax: cavity depth available on that assembly [m]
assemblies = pd.DataFrame(
    {
        "North wall": {"area": 40.0, "R0": 2.0, "tmax": 0.15},
        "East wall": {"area": 25.0, "R0": 1.6, "tmax": 0.12},
        "South wall": {"area": 40.0, "R0": 2.4, "tmax": 0.10},
        "Roof": {"area": 60.0, "R0": 3.0, "tmax": 0.25},
    }
).T

ALPHA = 60.0  # annualized energy cost per unit U   [$ K / W / m^2]
BETA = 0.05  # equivalent annual cost factor on capital
CREW = 150.0  # fixed crew/logistics charge per material stocked [$]
BUDGET = 900.0  # capital budget [$]

display(materials)
display(assemblies)
# Out:
#                          k     a       b   tmax
# Fiberglass batt      0.040   4.0    60.0  0.060
# Mineral wool         0.030   5.0   150.0  0.060
# Rigid foam (low R)   0.030   8.0   120.0  0.050
# Rigid foam (high R)  0.015   8.0   180.0  0.050
# Aerogel blanket      0.013  12.0   900.0  0.020
# Cellulose fill       0.038   3.0    45.0  0.080
# Polyiso board        0.022   7.0   160.0  0.050
# Vacuum panel         0.007  25.0  2500.0  0.015
#             area   R0  tmax
# North wall  40.0  2.0  0.15
# East wall   25.0  1.6  0.12
# South wall  40.0  2.4  0.10
# Roof        60.0  3.0  0.25

# %%
def build_retrofit_minlp(budget=BUDGET):
    """Build the whole-building insulation retrofit MINLP.

    Arguments:
        budget: capital budget on installed cost [$]

    Returns:
        a Pyomo ConcreteModel
    """
    m = pyo.ConcreteModel("insulation retrofit MINLP")
    m.N = pyo.Set(initialize=list(materials.index))
    m.W = pyo.Set(initialize=list(assemblies.index))

    m.x = pyo.Var(m.W, m.N, domain=pyo.NonNegativeReals, bounds=(0, 0.3))
    m.y = pyo.Var(m.W, m.N, domain=pyo.Binary)  # material n installed on assembly w
    m.z = pyo.Var(m.N, domain=pyo.Binary)  # material n stocked at all

    @m.Constraint(m.W, m.N)
    def layer_available(m, w, n):
        return m.x[w, n] <= materials.loc[n, "tmax"] * m.y[w, n]

    @m.Constraint(m.W, m.N)
    def stocked(m, w, n):
        return m.y[w, n] <= m.z[n]

    @m.Constraint(m.W)
    def thickness_budget(m, w):
        # [m] cavity depth available on that assembly
        return sum(m.x[w, n] for n in m.N) <= assemblies.loc[w, "tmax"]

    @m.Constraint()
    def capital_budget(m):
        # [$] installed cost, before annualization
        return (
            sum(
                assemblies.loc[w, "area"]
                * (
                    materials.loc[n, "a"] * m.y[w, n]
                    + materials.loc[n, "b"] * m.x[w, n]
                )
                for w in m.W
                for n in m.N
            )
            + CREW * sum(m.z[n] for n in m.N)
            <= budget
        )

    @m.Objective(sense=pyo.minimize)
    def cost(m):
        total = 0
        for w in m.W:
            # [m^2 K / W] series resistance of the assembly
            R = assemblies.loc[w, "R0"] + sum(
                m.x[w, n] / materials.loc[n, "k"] for n in m.N
            )
            total += assemblies.loc[w, "area"] * (
                ALPHA / R
                + BETA
                * sum(
                    materials.loc[n, "a"] * m.y[w, n]
                    + materials.loc[n, "b"] * m.x[w, n]
                    for n in m.N
                )
            )
        total += BETA * CREW * sum(m.z[n] for n in m.N)
        return total

    return m


def report(m, label):
    """Print the stocked materials and the layer schedule of a solved model."""
    print(f"{label}: annualized cost = {pyo.value(m.cost):.4f} $/yr")
    print(f"  stocked: {[n for n in m.N if pyo.value(m.z[n]) > 0.5]}")
    for w in m.W:
        layers = {
            n: round(pyo.value(m.x[w, n]), 4) for n in m.N if pyo.value(m.y[w, n]) > 0.5
        }
        print(f"  {w:12s} {layers}")

# %% [markdown]
# ### The reference answer
#
# Before benchmarking anything, get an answer you trust. **bonmin** is a dedicated MINLP solver (it
# implements NLP-based branch and bound and outer approximation, among others) and it is exact for convex
# problems, which this one is. Every strategy in Parts 1–3 is measured against this number.

# %%
m_ref = build_retrofit_minlp()
t0 = time.perf_counter()
results = pyo.SolverFactory("bonmin").solve(m_ref)
t_ref = time.perf_counter() - t0

assert pyo.check_optimal_termination(
    results
), f"bonmin failed: {results.solver.termination_condition}"

Z_REF = pyo.value(m_ref.cost)
report(m_ref, "bonmin")
print(f"  wall time = {t_ref:.2f} s")
# Out:
# bonmin: annualized cost = 2764.3022 $/yr
#   stocked: ['Cellulose fill']
#   North wall   {'Cellulose fill': 0.08}
#   East wall    {'Cellulose fill': 0.08}
#   South wall   {'Cellulose fill': 0.08}
#   Roof         {}
#   wall time = 0.63 s

# %% [markdown]
# ## Problem 1. One solve, and one check (10 points)
#
# Solve the same model with MindtPy's **outer approximation** strategy, using `appsi_highs` for the master
# MILPs and `ipopt` for the NLP subproblems.
#
# Then, before printing anything:
#
# 1. Assert that the termination condition is optimal.
# 2. Assert that the objective agrees with `Z_REF` to within $10^{-3}$.
#
# Print the objective, the number of major iterations, and the wall time.

# %%
m1 = build_retrofit_minlp()

# Add your solution here
# Out:
# WARNING: DEPRECATED: The `transform_deactivated_blocks` arguments is
# deprecated. Either specify deactivated Blocks as targets to activate them if
# transforming them is the desired behavior.  (deprecated in 6.9.3) (called from
# /Users/adowling/opt/anaconda3/envs/optimization_fall2026/lib/python3.13/site-
# packages/pyomo/core/base/transformation.py:75)
# MindtPy OA: cost = 2764.3021 $/yr
#   major iterations = 4
#   wall time        = 3.03 s

# %% [markdown]
# **Question 1a.** Outer approximation solves one NLP and one MILP per major iteration. Look at the
# iteration count you just printed. How many NLP solves is that, and how does it compare with the
# $2^{40}$ that complete enumeration would need? What is doing the work of eliminating the rest?

# %%
# Add your solution here
# Out:
# Four major iterations, so four NLP subproblems (plus one relaxed NLP for the initialization), against
# $2^{40} \approx 1.1 \times 10^{12}$ for enumeration.
#
# The elimination is done by the *master problem*, not by the NLPs. Each major iteration adds a block of
# linearized rows and one integer cut to a MILP over all 40 binaries, and that MILP is solved to global
# optimality by HiGHS — which itself runs branch and cut internally. So the combinatorial search happens
# once per iteration, inside a linear solver that is very good at it, and the expensive nonlinear work is
# done only at the handful of designs the master problem actually proposes. That division of labour is the
# whole point of outer approximation: *few NLPs, many MILPs*.

# %% [markdown]
# ## Problem 2. The strategy sweep (30 points)
#
# MindtPy 6.10.1 advertises four strategies. Try all four on the same model and tabulate what happens.
#
# **Do not assume they all work.** One of them requires a compiled library that is not part of this course
# environment. Your loop must catch the exception, record it, and keep going — a benchmark that dies on the
# third row is not a benchmark.
#
# Write a function `benchmark(strategy, **options)` that
#
# * builds a fresh model (never reuse a solved one — the warm start would contaminate the comparison),
# * times the solve,
# * returns a dict with keys `strategy`, `termination`, `objective`, `iterations`, `time [s]`, and
#   `gap vs bonmin`,
# * and on an exception returns the exception type and message in place of the numbers.
#
# Then run it for `"OA"`, `"ECP"`, `"GOA"`, `"FP"` and display the table.

# %%
def benchmark(strategy, model_builder=build_retrofit_minlp, reference=None, **options):
    """Run one MindtPy strategy on a fresh model and summarize the outcome.

    Arguments:
        strategy: MindtPy strategy string, e.g. "OA"
        model_builder: zero-argument callable returning a fresh ConcreteModel
        reference: objective value to compare against, or None
        **options: extra keyword arguments passed to MindtPy

    Returns:
        a dict of results; on failure, the exception type and message
    """
    # Add your solution here


# Add your solution here
# Out:
# FP-MIP infeasible
#              termination  objective  iterations  time [s]  gap vs bonmin  \
# strategy
# OA               optimal  2764.3021         4.0    2.5390        -0.0001
# ECP              optimal  2764.3052         5.0    0.1865         0.0030
# GOA       AttributeError        NaN         NaN       NaN            NaN
# FP                  None  3041.5512         0.0    1.0631       277.2490
#
#                                                        note
# strategy
# OA
# ECP
# GOA       dlsym(RTLD_DEFAULT, get_version): symbol not f...
# FP                                              NOT optimal

# %% [markdown]
# **Question 2a — GOA.** One row failed. Report the exception, then explain in one sentence what MindtPy was
# trying to do when it failed, and why global outer approximation needs machinery that outer approximation
# does not. The following cell will help you diagnose it.

# %%
from pyomo.contrib.mcpp.pyomo_mcpp import mcpp_available

print("MC++ library available:", mcpp_available())
# Out:
# MC++ library available: False

# %%
# Add your solution here
# Out:
# `GOA` raises `AttributeError: dlsym(RTLD_DEFAULT, get_version): symbol not found`, from
# `pyomo/contrib/mcpp/pyomo_mcpp.py`, and `mcpp_available()` returns `False`.
#
# MindtPy was trying to build an **affine cut** from a McCormick relaxation of the constraint body, using
# the MC++ library. Ordinary outer approximation cuts are just first-order Taylor expansions, which are
# valid underestimators *only because the functions are convex*; global outer approximation makes no
# convexity assumption, so it cannot use a tangent plane and must instead construct a rigorous convex
# underestimator of a possibly nonconvex function — which is what MC++ computes. MC++ is a compiled C++
# library that is not built in the course environment, so GOA is unavailable here.
#
# The point worth keeping: **the option exists but the guarantee it offers is expensive to implement.**
# Part 4 shows what it would have been protecting you from.

# %% [markdown]
# **Question 2b — FP.** The feasibility pump row is the trap this assignment is built around. Report its
# termination condition and its objective. Is the objective feasible? Is it optimal? Would
# `pyo.check_optimal_termination` have caught it?
#
# Then explain, in terms of the two bounds $z^u$ and $z^L$ from the handout, why the feasibility pump can
# *never* return a proof of optimality no matter how long you run it.

# %%
# Add your solution here
# Out:
# FP returns termination condition **`None`** and an objective of about **3041.55**, against bonmin's
# **2764.30** — a **10 % error**, reported without any complaint. `pyo.check_optimal_termination` returns
# `False` for it, so the check required by the style guide *does* catch it. Nothing else does: the number
# looks entirely reasonable, and it is a genuinely feasible design.
#
# The reason is structural. Outer approximation maintains two bounds: an upper bound $z^u$ from the NLP
# subproblems (every one of which is a *restriction*, hence feasible) and a lower bound $z^L$ from the MILP
# master problem (a *relaxation*). Optimality is proved when $z^u - z^L < \varepsilon$ — it is the closing
# of the gap, not the value of $z^u$, that constitutes the proof.
#
# The feasibility pump only ever produces upper bounds. It alternates between rounding an NLP solution to
# integers and projecting an integer point back onto the continuous feasible set, and it stops the moment
# those two agree. It never builds a relaxation, so it never has a $z^L$, so there is no gap to close. It is
# a *primal heuristic*: its job is to hand a good starting point to something else. That is precisely how
# MindtPy uses it internally, as `init_strategy="FP"` in Problem 3.

# %% [markdown]
# **Question 2c — ECP.** The extended cutting plane method reaches an objective close to, but not exactly,
# bonmin's, and it does so much faster than OA. Report both numbers. Then explain the mechanism: what does
# ECP do at each iteration that OA does *not* do, and how does that account for both the speed and the
# residual error?

# %%
# Add your solution here
# Out:
# ECP returns 2764.3052 in about 0.2 s and 5 iterations; OA returns 2764.3021 in about 3 s and 4
# iterations -- an order of magnitude apart on the clock, despite the similar iteration counts. The discrepancy is $3.1 \times 10^{-3}$, roughly one part in $10^{6}$.
#
# **ECP never solves an NLP.** Where outer approximation, at each major iteration, fixes $y$ and solves a
# nonlinear subproblem for $x$, ECP simply evaluates the nonlinear constraints and objective at the master
# problem's current solution, adds a linearization at that point, and re-solves the MILP. It is the
# cutting-plane idea of handout §2 applied to nonlinearity rather than to integrality: an outer
# approximation of the nonlinear feasible set, refined until the violation falls below a tolerance.
#
# That explains both observations.
#
# * **The speed.** Ipopt is never called. Every iteration is one MILP plus a function and gradient
#   evaluation, and HiGHS warm-starts across iterations. An order of magnitude is exactly what you would
#   expect.
# * **The residual error.** ECP terminates on *constraint violation*, not on a bound gap closed by a
#   feasible NLP solution. Its final point satisfies the nonlinear constraints only to within the ECP
#   tolerance, so its objective is not the exact value at an exactly feasible point. OA's upper bound, by
#   contrast, always comes from a converged NLP solve and is feasible to Ipopt's tolerance.
#
# So ECP trades a small, controlled infeasibility for a large speedup — which is a good trade when the NLP
# is expensive and a bad one when the constraints are things like mass balances that must actually hold.

# %% [markdown]
# ## Problem 3. Toggling outer approximation (25 points)
#
# `strategy="OA"` is not one algorithm; it is a family. Three options change it substantially.
#
# **(a) `init_strategy=`** — where the first $y^{1}$ comes from. In the notebook we started from a
# deliberately poor guess (aerogel alone) and watched it cost an iteration. MindtPy offers
#
# | value | what it does |
# | --- | --- |
# | `"rNLP"` | solve the fully relaxed NLP (integrality dropped) and round — the default |
# | `"max_binary"` | maximize the sum of the binaries subject to the linear constraints |
# | `"initial_binary"` | use the values already stored in the model's binary variables |
# | `"FP"` | run the feasibility pump from Problem 2 as an initializer |
#
# Benchmark all four. `"initial_binary"` requires that *every* binary already have a value — set them
# yourself first, and use the answer to Problem 1 as a warm start to see the best case.
#
# **(b) `add_no_good_cuts=`** — whether to add the integer cut that forbids revisiting a $y^{k}$. Try
# `True` and `False`.
#
# **(c) `single_tree=`** — MindtPy's LP/NLP-based branch and bound, which solves *one* MILP tree and calls
# the NLP from a solver callback instead of restarting the tree every iteration. Try it and report what
# happens.

# %%
# Add your solution here
# Out:
# FP-MIP infeasible
# type NoneType doesn't define __round__ method
# Traceback (most recent call last):
#   File "/Users/adowling/opt/anaconda3/envs/optimization_fall2026/lib/python3.13/site-packages/pyomo/contrib/mindtpy/algorithm_base_class.py", line 1050, in MindtPy_initialization
#     self.curr_int_sol = get_integer_solution(self.working_model)
#                         ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/Users/adowling/opt/anaconda3/envs/optimization_fall2026/lib/python3.13/site-packages/pyomo/contrib/mindtpy/util.py", line 653, in get_integer_solution
#     temp.append(int(round(var.value)))
#                     ~~~~~^^^^^^^^^^^
# TypeError: type NoneType doesn't define __round__ method
#                                                    termination  objective  \
# strategy
# OA  (init_strategy=rNLP)                               optimal  2764.3021
# OA  (init_strategy=max_binary)                         optimal  2764.3021
# OA  (init_strategy=FP)                                 optimal  2764.3021
# OA  (init_strategy=initial_binary)  [warm started]     optimal  2764.3021
# OA  (init_strategy=initial_binary)  [no values ...  ValueError        NaN
# OA  (add_no_good_cuts=True)                            optimal  2764.3021
# OA  (add_no_good_cuts=False)                           optimal  2764.3021
# OA  (single_tree=True)                              ValueError        NaN
#
#                                                     iterations  time [s]  \
# strategy
# OA  (init_strategy=rNLP)                                   4.0    2.2627
# OA  (init_strategy=max_binary)                             4.0    1.3926
# OA  (init_strategy=FP)                                     2.0    2.3758
# OA  (init_strategy=initial_binary)  [warm started]         3.0    2.0860
# OA  (init_strategy=initial_binary)  [no values ...         NaN       NaN
# OA  (add_no_good_cuts=True)                                4.0    4.1454
# OA  (add_no_good_cuts=False)                               4.0    1.8511
# OA  (single_tree=True)                                     NaN       NaN
#
#                                                     gap vs bonmin  \
# strategy
# OA  (init_strategy=rNLP)                                  -0.0001
# OA  (init_strategy=max_binary)                            -0.0001
# OA  (init_strategy=FP)                                    -0.0001
# OA  (init_strategy=initial_binary)  [warm started]        -0.0001
# OA  (init_strategy=initial_binary)  [no values ...            NaN
# OA  (add_no_good_cuts=True)                               -0.0001
# OA  (add_no_good_cuts=False)                              -0.0001
# OA  (single_tree=True)                                        NaN
#
#                                                                                                  note
# strategy
# OA  (init_strategy=rNLP)
# OA  (init_strategy=max_binary)
# OA  (init_strategy=FP)
# OA  (init_strategy=initial_binary)  [warm started]
# OA  (init_strategy=initial_binary)  [no values ...  The initial integer combination is not provide...
# OA  (add_no_good_cuts=True)
# OA  (add_no_good_cuts=False)
# OA  (single_tree=True)                              Only cplex_persistent and gurobi_persistent ar...

# %% [markdown]
# **Question 3a.** Every row that ran returned the same objective. Given that, what *is* the initialization
# buying, and which row bought the most? Tie your answer to the role $y^{1}$ plays in the handout's
# flowchart.

# %%
# Add your solution here
# Out:
# The objective is invariant because outer approximation is EXACT for a convex MINLP regardless of where it
# starts. The master problem is a valid relaxation from any y^1, so the gap can only close at the true
# optimum. Initialization buys ITERATIONS, not correctness.
#
# What y^1 controls is where the first tangent plane is placed. A good y^1 puts it near the optimum, so the
# very first master problem already has a tight lower bound and few designs survive; a bad one puts it
# somewhere irrelevant and the first bound is nearly useless -- exactly what section 2 of the notebook
# showed, where the aerogel-only start produced a first lower bound far below anything achievable.
#
# Measured here, in major iterations:
#
#     rNLP (default)              4
#     max_binary                  4
#     FP                          2
#     initial_binary, warm        3
#
# FP bought the most. The strategy that could not prove anything on its own in Problem 2 turns out to be
# very good at what it is actually for: handing a nearly optimal integer point to a method that CAN prove
# things.
#
# Note carefully that this did NOT show up as a proportional speedup. FP halves the iteration count and
# saves little or no wall time -- sometimes none at all -- because the pump itself costs several NLP and MILP
# solves before the main loop even starts, and this problem's NLP subproblems are small enough that saving
# two of them does not pay for that. (Re-run the cell: the ordering of the wall times is not even stable,
# while the iteration counts are identical every time. The same OA configuration timed over 4 s in Problem 1
# and under 3 s here.) The right conclusion is that iteration count and wall time measure different things,
# and at this problem size only the iteration counts are worth reporting. On a problem whose NLP subproblems took minutes rather than
# milliseconds, halving the iteration count would be the whole ballgame.
#
# The warm-started row is also not free: it needed the Problem 1 answer to exist. In practice the warm start
# comes from a previous, similar design case -- which is the normal situation in engineering.

# %% [markdown]
# **Question 3b.** `single_tree=True` failed. Report the message, and explain why the LP/NLP-based branch
# and bound method cannot be implemented on top of `appsi_highs`. What would you have to install?

# %%
# Add your solution here
# Out:
# `ValueError: Only cplex_persistent and gurobi_persistent are supported for LP/NLP based Branch and Bound
# method.`
#
# Single-tree OA does not restart the MILP from scratch at each major iteration. It builds **one** branch and
# bound tree and installs a *lazy constraint callback*: whenever the tree finds an integer-feasible node,
# the callback pauses the search, solves the NLP subproblem at that $y$, generates the outer approximation
# cut, injects it into the live tree, and lets the search continue. All the branching work already done is
# retained.
#
# That requires the MILP solver to expose a callback API and to let a client add constraints mid-solve.
# HiGHS, through the APPSI interface Pyomo uses here, does not — Pyomo can only hand it a complete model and
# take back a solution. Only the persistent interfaces to **CPLEX** or **Gurobi** expose the necessary
# callbacks, and both are commercial (though both have free academic licenses). Installing either one, plus
# its Python bindings, would make `single_tree=True` available.
#
# This is a good illustration of a general point: the algorithm you can run is constrained by the *interface*
# your solver exposes, not only by its numerics.

# %% [markdown]
# **Question 3c.** `add_no_good_cuts=False` still converged, and to the right answer. In the notebook's
# hand-written `outer_approximation`, removing the integer cut would have caused an infinite loop. Why does
# MindtPy survive without it?

# %%
# Add your solution here
# Out:
# Because MindtPy's master problem also carries the **epigraph bound** $\alpha \le z^u - \varepsilon$ (its
# `oa_cuts` block is accompanied by an objective cut-off at the incumbent). Once a design has been evaluated,
# its own tangent plane forces $\alpha \ge z^u_k$ at that $y$, and the cut-off forces $\alpha < z^u$, so the
# design is infeasible in the next master problem *without* an explicit integer cut. The accumulated
# linearizations do the excluding.
#
# The notebook's implementation has no such cut-off — its master problem minimizes $\alpha$ with no upper
# restriction — so an already-visited $y$ remains feasible and would be proposed again forever. The integer
# cut is what supplies the exclusion there.
#
# Which mechanism you use matters for nonconvex problems: an integer cut is combinatorial and always valid,
# whereas the objective cut-off relies on the tangent plane being a genuine underestimator. That is a hint
# about Part 4.

# %% [markdown]
# ## Problem 4. Where outer approximation stops being an algorithm (25 points)
#
# Everything above rested on convexity. The handout is explicit about it: the tangent plane in the master
# problem is a valid *underestimator* only because $f$ and $g$ are convex, and without that the "lower
# bound" is not a bound at all.
#
# Here is the notebook's five-material single-wall problem with **one** change: the capital cost of a layer
# has economies of scale,
#
# $$
# \text{capital}_n(x_n) \;=\; b_n \, s \left[ (x_n + \epsilon)^{p} - \epsilon^{p} \right],
# \qquad p = 0.6, \quad s = 8, \quad \epsilon = 10^{-4},
# $$
#
# which is **concave** in $x_n$ — the second unit of thickness costs less than the first, because the crew
# is already on site. That is entirely realistic, and it makes the objective nonconvex.

# %%
SCALE = 8.0  # cost multiplier on the concave capital term
EXPO = 0.6  # < 1 makes it concave: economies of scale
EPS = 1e-4  # offset keeping the derivative finite at x = 0
R0 = 2.0  # resistance of the structural elements  [m^2 K / W]
T_TOTAL = 0.15  # total thickness the wall cavity allows [m]
NC_MATERIALS = list(materials.index[:5])


def build_nonconvex_minlp(x_init=0.005):
    """Single-wall insulation MINLP with a concave (economies-of-scale) capital cost.

    Arguments:
        x_init: value every thickness variable is initialized at [m]

    Returns:
        a Pyomo ConcreteModel -- NONCONVEX
    """
    m = pyo.ConcreteModel("nonconvex insulation MINLP")
    m.N = pyo.Set(initialize=NC_MATERIALS)
    m.x = pyo.Var(m.N, domain=pyo.NonNegativeReals, bounds=(0, 0.06), initialize=x_init)
    m.y = pyo.Var(m.N, domain=pyo.Binary, initialize=0)

    @m.Constraint(m.N)
    def layer_available(m, n):
        return m.x[n] <= materials.loc[n, "tmax"] * m.y[n]

    @m.Constraint()
    def thickness_budget(m):
        return sum(m.x[n] for n in m.N) <= T_TOTAL

    @m.Objective(sense=pyo.minimize)
    def cost(m):
        R = R0 + sum(m.x[n] / materials.loc[n, "k"] for n in m.N)
        return ALPHA / R + BETA * sum(
            materials.loc[n, "a"] * m.y[n]
            + materials.loc[n, "b"] * SCALE * ((m.x[n] + EPS) ** EXPO - EPS**EXPO)
            for n in m.N
        )

    return m

# %% [markdown]
# **(a)** Plot the capital cost of one material against thickness, both the original linear form $b_n x_n$
# and the concave form, and confirm visually that the new one is concave.
#
# **(b)** Solve the model with **couenne**, which is a spatial branch and bound code and is therefore a
# *rigorous global* solver — it does not assume convexity. This is the reference.
#
# **(c)** Solve it with MindtPy `strategy="OA"` from six different initializations
# (`x_init` $\in \{0, 0.001, 0.005, 0.01, 0.03, 0.06\}$) and tabulate the objective, the design, and the
# termination condition for each.

# %%
# Add your solution here

# %%
# Add your solution here
# Out:
# couenne (global): cost = 21.6889 $/m^2
#   layers = ['Fiberglass batt']

# %%
# Add your solution here
# Out:
#            termination  objective  error vs global             layers  \
# x_init [m]
# 0.000          optimal    21.6889           0.0000  [Fiberglass batt]
# 0.001          optimal    21.6889           0.0000  [Fiberglass batt]
# 0.005          optimal    30.0000           8.3111                 []
# 0.010          optimal    30.0000           8.3111                 []
# 0.030          optimal    30.0000           8.3111                 []
# 0.060          optimal    30.0000           8.3111                 []
#
#             time [s]
# x_init [m]
# 0.000         0.7355
# 0.001         0.6832
# 0.005         0.7438
# 0.010         1.5055
# 0.030         1.6476
# 0.060         1.4910

# %% [markdown]
# **Question 4a.** Summarize the table in two sentences. What is the largest error, in percent? What
# termination condition did MindtPy report in the rows that were wrong?

# %%
# Add your solution here
# Out:
# Couenne finds the global optimum **21.6889 $/m²** — install a single layer of fiberglass batt, whose
# concave cost makes a thick layer of the cheapest material the right answer. MindtPy's outer approximation
# finds that answer from `x_init` $\in \{0, 0.001\}$ and returns **30.0000** from all four larger starting
# points, which is the do-nothing design ($y = 0$, cost $= \alpha/R_0 = 60/2$): a **38 % error**, reported
# with `termination_condition = optimal` every single time.
#
# Two sentences is generous. One suffices: *on a nonconvex MINLP, outer approximation returns a
# starting-point-dependent answer and calls it optimal.*

# %% [markdown]
# **Question 4b.** Explain the failure mechanism precisely, in the language of the handout. Which of the two
# bounds is invalid, and what does the algorithm's termination test then actually test? Draw the tangent
# plane to the concave cost at $x = 0.005$ on your plot from (a) if it helps.

# %%
# Add your solution here
# Out:
# The **lower bound $z^L$ is invalid**.
#
# Outer approximation's master problem replaces $f(x)$ with the tangent plane
# $f(x^{k}) + \nabla f(x^{k})^\top (x - x^{k})$. For a convex $f$ that plane lies *below* $f$ everywhere, so
# the master problem is a genuine relaxation and its optimal value is a genuine lower bound. For a **concave**
# $f$ the tangent plane lies *above* $f$ everywhere — the plot in (a) makes this immediate: the tangent to
# the concave curve at $x = 0.005$ is above the curve for every $x \ne 0.005$.
#
# The consequence is that the master problem is a *restriction*, not a relaxation. It systematically
# **overestimates** the cost of thick layers, which is precisely where the true optimum lives, so the design
# that is actually cheapest looks expensive to the master problem and is never proposed. The algorithm then
# adds an integer cut, tries the remaining candidates, runs out, and reports the best thing it saw.
#
# The termination test $z^u - z^L < \varepsilon$ still fires — but $z^L$ is no longer a lower bound on
# anything, so what the test now certifies is only that *the master problem agrees with itself*. There is no
# statement about the true optimum at all. That is why the solver says `optimal` and is wrong: it is
# reporting the outcome of its own convergence test faithfully, and the test has lost its meaning.
#
# The rows that got the right answer got it by luck: `x_init` near zero happens to place the first
# linearization where the resulting overestimate does not cut off the optimum.

# %% [markdown]
# **Question 4c.** What *would* be the right tool here, and what would it cost? Name three options, and for
# each say what it gives up. (One of them you already met in Problem 2.)

# %%
# Add your solution here
# Out:
# 1. **A spatial branch and bound global solver — couenne, BARON, SCIP, Gurobi's nonconvex mode.** It
#    replaces the tangent plane with a *rigorous convex underestimator* (McCormick envelopes, $\alpha$BB,
#    piecewise secants) that is valid without convexity, and branches on the *continuous* variables to
#    tighten it. What it gives up is speed: the bound is much weaker than a tangent plane, so the tree is
#    much larger, and worst-case effort grows exponentially in the number of nonconvex terms. This is the
#    subject of [](../8/Global-Opt.ipynb).
#
# 2. **MindtPy's `strategy="GOA"`.** The same idea inside the OA framework — the cuts are built from
#    McCormick relaxations rather than Taylor expansions. What it gives up here is *availability*: it needs
#    the MC++ library, which is not installed in this environment (Problem 2a).
#
# 3. **Reformulate so the problem becomes convex.** Concave cost curves are very often piecewise-linearized
#    with SOS2 variables or a disjunctive/big-M formulation, turning a nonconvex NLP into an exactly-solvable
#    MILP with more binaries. What it gives up is exactness of the *model* — the piecewise fit is an
#    approximation of the cost curve — traded for exactness of the *solution*. In practice this is the most
#    common answer in process systems engineering, and it is the reason the logical-modeling lecture came
#    before this one.
#
# A fourth, honest, non-answer that is nevertheless what many people do: **run OA from many starting points
# and take the best.** That yields a good feasible design and no guarantee whatsoever, which is fine as long
# as nobody writes "optimal" in the report.

# %% [markdown]
# ## Problem 5. Short answer (10 points)
#
# Answer in two or three sentences each. These are the connections the assignment is testing; no code is
# needed.
#
# **5a.** The notebook's generalized Benders implementation took four major iterations where outer
# approximation took three, on the same problem from the same start. MindtPy has no `strategy="GBD"`. Given
# what you found in Problem 2 about the cost of each strategy, and the bound inequality
# $z^L_{\text{GBD}} \le z^L_{\text{OA}}$, why might that omission be defensible — and when would you want it
# back?

# %%
# Add your solution here
# Out:
# GBD's whole advantage is a smaller master problem: one row per iteration instead of $1 + r$, with the
# continuous variables projected out. That mattered enormously when MILP solvers were weak; with HiGHS,
# CPLEX or Gurobi the master problem is almost never the bottleneck, and the NLP subproblems — of which GBD
# needs *more*, because its bound is weaker — are. So on modern hardware GBD usually loses to OA on exactly
# the metric that costs money.
#
# You want it back when the master problem *is* the bottleneck: very large $r$ (thousands of coupled
# inequalities), or a structure where fixing $y$ decomposes the NLP into independent blocks that can be
# solved in parallel — which is the two-stage stochastic programming case, where the "Benders cut" per
# scenario is the L-shaped method. There, one cut per scenario per iteration is the only thing that keeps
# the master problem tractable.

# %% [markdown]
# **5b.** Handout §2 says pure cutting-plane methods are not used to solve integer programs because of
# numerical instability, and §3 says the fix is branch and cut. ECP in Problem 2 *is* a cutting-plane method,
# and it worked fine and fast. Reconcile these.

# %%
# Add your solution here
# Out:
# The instability in §2 comes from generating cuts *recursively from a tableau that already contains the
# previous cuts*: Gomory cut $k+1$ is read off a simplex tableau of a problem containing cuts $1 \dots k$, so
# coefficients grow, rows become near-parallel, the basis becomes ill-conditioned, and eventually a "cut" is
# numerical noise that can remove feasible integer points.
#
# ECP's cuts are not generated that way. Each one is a first-order Taylor expansion of a *fixed, known*
# nonlinear function evaluated at a point — the coefficients are gradients of $g$ and $f$, quantities of
# bounded magnitude that do not depend on the cuts already added. There is no recursion and no accumulation
# of round-off, so the conditioning does not degrade. Same word, "cut"; completely different provenance.
#
# (ECP has its own weakness, seen in Problem 2c: it terminates on constraint violation, so its answer is only
# as feasible as its tolerance.)

# %% [markdown]
# **5c.** Across this whole assignment, exactly one line of defensive code would have caught the FP error in
# Problem 2 and none of the errors in Problem 4. Name it, and say what a working engineer should conclude
# about how far solver status checking goes.

# %%
# Add your solution here
# Out:
# `assert pyo.check_optimal_termination(results)`. FP returns `termination_condition = None`, so the assert
# fires. Every wrong answer in Problem 4 comes back as `optimal`, so it does not.
#
# The conclusion is that the status check is **necessary and not sufficient**. It catches the solver
# *failing* — infeasible, unbounded, iteration limit, no proof attempted. It cannot catch the solver
# *succeeding at the wrong problem*, which is what happens when a method's assumptions are violated: the
# convergence test is internally consistent and externally meaningless. Guarding against that takes something
# the solver cannot supply — knowing whether your model is convex, cross-checking against a second solver of
# a different class (as every notebook in this course does with bonmin or couenne), and being suspicious of
# an answer that sits exactly on a trivial design like "install nothing."

# %% [markdown]
# ## Declarations
#
# **Collaboration.** List everyone you discussed this assignment with.
#
# **AI use.** Per the course AI policy, state which tools you used, for which problems, and what you did to
# verify their output.
