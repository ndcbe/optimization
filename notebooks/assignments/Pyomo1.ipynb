# %% [markdown]
# # Pyomo Homework 1

# %% [markdown]
# ```{warning}
# **This is a draft assignment. It is still being updated for Fall 2026.**
# ```

# %%
# This code cell installs packages on Colab

import sys

if "google.colab" in sys.modules:
    # !wget "https://raw.githubusercontent.com/ndcbe/optimization/main/notebooks/helper.py"
    import helper

    helper.easy_install()
else:
    sys.path.insert(0, "../")
    import helper
helper.set_plotting_style()

# %%
## IMPORT LIBRARIES
import pyomo.environ as pyo
import pandas as pd

# %% [markdown]
# ## How this assignment is organized
#
# This homework has **four problems**. The first two are **pencil and paper** --- no solver, no code
# cell. They are deliberately written in the format of the in-person midterm, so that the exam is not
# the first time you see these questions.
#
# | # | Problem | Format |
# | --- | --- | --- |
# | 1 | Student diet | pencil and paper, **answers published** |
# | 2 | Portfolio optimization | pencil and paper, **answers published** |
# | 3 | Nonlinear programs: initialization and formulation | code |
# | 4 | Reactor design | code |
#
# :::{important}
# **Problems 1 and 2 are graded on completion, which is why the answers are published below each
# question.** Attempt each part **cold, on paper, with the answer still collapsed.** Then expand it and
# mark your own work. Reading the answer first costs you the only thing these two problems are for.
# :::

# %% [markdown]
# ## Problem 1. Student diet
#
# *Pencil and paper. Attempt every part before expanding an answer.*
#
# **Background.** You want to save money eating while remaining healthy. A healthy diet requires at
# least $P = 6$ units of protein, $C = 15$ units of carbohydrates, $F = 5$ units of fats and $V = 7$
# units of vitamins per day. Due to compounding factors (blizzard during Lent), campus only has these
# options:
#
# | | P | C | F | V | price (USD/serving) |
# | --- | --- | --- | --- | --- | --- |
# | takeaway | 3 | 3 | 2 | 1 | 5 |
# | vegetables | 1 | 2 | 0 | 4 | 1 |
# | bread | 0.5 | 4 | 1 | 0 | 2 |
#
# **Instruction.** Consider the following Python and Pyomo code, which should NOT contain any mistakes.
#
# ```python
# # Data. food_options is the table above, read from ../data/student_diet.csv
# nutrients = food_options.columns.to_list()[0:4]     # ['P', 'C', 'F', 'V']
# foods = food_options.index.to_list()                # ['takeaway', 'vegetables', 'bread']
# food_info = food_options[nutrients].stack().to_dict()   # {('takeaway', 'P'): 3, ...}
# price = food_options["price"].to_dict()                 # {'takeaway': 5, ...}
# nutrient_requirements = {"P": 6, "C": 15, "F": 5, "V": 7}
#
# m = pyo.ConcreteModel()
#
# ## Define sets
# m.FOOD = pyo.Set(initialize=foods)
# m.NUTRIENTS = pyo.Set(initialize=nutrients)
#
# ## Define parameters
# m.needs = pyo.Param(m.NUTRIENTS, initialize=nutrient_requirements, units=u.nutrient)
# m.food_info = pyo.Param(
#     m.FOOD, m.NUTRIENTS, initialize=food_info, units=u.nutrient / u.serving
# )
# m.price = pyo.Param(m.FOOD, initialize=price, units=u.USD / u.serving)
#
# ## Define variables
# m.food_eaten = pyo.Var(
#     m.FOOD, initialize=1.0, domain=pyo.NonNegativeReals, units=u.serving
# )
#
#
# ## Define constraints
# # C1
# @m.Constraint(m.NUTRIENTS)
# def diet_min(b, n):
#     return sum(b.food_info[f, n] * b.food_eaten[f] for f in b.FOOD) >= b.needs[n]
#
#
# ## Define objective
# @m.Objective(sense=pyo.minimize)
# def cost(b):
#     return sum(b.food_eaten[f] * b.price[f] for f in b.FOOD)
# ```
#
# Solving this model with Ipopt gives:
#
# ```
# Units of takeaway eaten = 1.0
# Units of vegetables eaten = 1.5
# Units of bread eaten = 3.0
# Total cost = 12.50 USD/day
# ```

# %% [markdown]
# ### 1-A. Translate the Pyomo code into a mathematical model (symbols and equations) using set notation similar to our in-class examples
#
# Next to each set, parameter, variable, and equation, write a few-word description.
#
# **Sets.**
#
# **Parameters (Data).** *Hint*: state the units of each one.
#
# **Variables.**
#
# **Objective.** (write mathematical equations)
#
# **Constraints.** Write mathematical equations. After C1, write a brief description. You are filling
# in the missing Python comments here. *Hint*: one restriction on the variables is **not** written as
# a Pyomo `Constraint`. Where does it come from, and does it belong in your mathematical model?
#
# <!-- BEGIN PUBLISHED ANSWER -->
# :::{dropdown} Click to check your answer to 1-A
#
# **Sets.**
#
# $\mathcal{F} = \{\text{takeaway}, \text{vegetables}, \text{bread}\}$ &nbsp;&nbsp; food options
# (`m.FOOD`)
#
# $\mathcal{N} = \{P, C, F, V\}$ &nbsp;&nbsp; nutrients (`m.NUTRIENTS`)
#
# **Parameters (Data).**
#
# $\pi_i$ &nbsp; [USD/serving] &nbsp;&nbsp; price of food $i \in \mathcal{F}$ (`m.price`)
#
# $D_{i,j}$ &nbsp; [nutrient/serving] &nbsp;&nbsp; units of nutrient $j \in \mathcal{N}$ in one serving
# of food $i \in \mathcal{F}$ (`m.food_info`)
#
# $r_j$ &nbsp; [nutrient] &nbsp;&nbsp; daily requirement for nutrient $j \in \mathcal{N}$ (`m.needs`)
#
# **Variables.**
#
# $x_i$ &nbsp; [serving] &nbsp;&nbsp; servings of food $i \in \mathcal{F}$ eaten per day
# (`m.food_eaten`)
#
# **Objective.**
#
# $$
# \min_{x} \quad \sum_{i \in \mathcal{F}} \pi_i \, x_i \qquad \text{(total cost of the diet, USD/day)}
# $$
#
# **Constraints.**
#
# $$
# \text{C1:} \quad \sum_{i \in \mathcal{F}} D_{i,j} \, x_i \; \geq \; r_j, \qquad \forall \, j \in \mathcal{N}
# $$
#
# *Be healthy*: the diet must supply at least the daily requirement of every nutrient. One inequality
# per nutrient, so C1 is $|\mathcal{N}| = 4$ inequalities.
#
# $$
# x_i \; \geq \; 0, \qquad \forall \, i \in \mathcal{F}
# $$
#
# *Non-negativity*: you cannot eat a negative amount of bread. This one is **not** a Pyomo
# `Constraint` --- it comes from `domain=pyo.NonNegativeReals` on `m.food_eaten`. It still belongs in
# the mathematical model. Pyomo hands it to the solver as a **variable bound** rather than a row of
# the constraint matrix, which is why 1-B counts bounds separately.
# :::
# <!-- END PUBLISHED ANSWER -->

# %% [markdown]
# ### 1-B. Degree of freedom analysis
#
# Count the continuous variables, the equality constraints, and the inequality constraints
# **separately**, and report the degrees of freedom. Then answer: why is it acceptable for this model
# to have more inequality constraints than variables?
#
# <!-- BEGIN PUBLISHED ANSWER -->
# :::{dropdown} Click to check your answer to 1-B
#
# | | Count |
# | --- | --- |
# | Continuous variables | 3 &nbsp; ($|\mathcal{F}| = 3$) |
# | Integer/discrete variables | 0 |
# | Equality constraints | 0 |
# | Inequality constraints | 4 &nbsp; ($|\mathcal{N}| = 4$, from C1) |
# | Variable bounds | 3 &nbsp; ($x_i \geq 0$) |
#
# **Degrees of freedom** $= 3 \text{ variables} - 0 \text{ equality constraints} = 3$.
#
# **Why more inequalities than variables is fine.** An inequality constraint only removes a degree of
# freedom when it is **active** (holds with equality) at the solution. At most 3 of the 7 inequalities
# and bounds can be active at a vertex of a 3-variable problem. Here exactly three are: at the
# optimum the diet supplies $P = 6$, $F = 5$ and $V = 7$ --- all binding --- but $C = 18 > 15$, so the
# carbohydrate constraint is **slack**. Bread and vegetables carry so much carbohydrate that meeting
# the other three requirements oversupplies it for free.
#
# An equality constraint, by contrast, always removes a degree of freedom, which is why the two are
# counted separately.
# :::
# <!-- END PUBLISHED ANSWER -->

# %% [markdown]
# ### 1-C. Problem size
#
# Let $N_f$ represent the number of food options and $N_n$ represent the number of nutrients. Using
# these symbols, determine the variables and constraints in your model. After each header below, give
# a number with a brief justification.
#
# **Number of continuous variables:**
#
# **Number of integer/discrete variables:**
#
# **Number of equality constraints:**
#
# **Number of inequality constraints:**
#
# **Number of parameters (data values) you must supply:**
#
# <!-- BEGIN PUBLISHED ANSWER -->
# :::{dropdown} Click to check your answer to 1-C
#
# **Continuous variables: $N_f$.** One serving variable $x_i$ per food option.
#
# **Integer/discrete variables: 0.** Every variable is declared `NonNegativeReals`. Servings are
# divisible in this model --- half a loaf of bread is allowed.
#
# **Equality constraints: 0.** The model contains only `>=` constraints. Nothing forces the diet to
# hit a requirement exactly.
#
# **Inequality constraints: $N_n$**, from C1 --- one per nutrient --- **plus $N_f$ variable bounds**
# $x_i \geq 0$. Whether you report $N_n$ or $N_n + N_f$ depends on whether you count bounds as
# constraints; say which convention you used.
#
# **Parameters: $N_f N_n + N_f + N_n$.** The nutrition table $D_{i,j}$ alone has $N_f N_n$ entries,
# plus $N_f$ prices and $N_n$ requirements. **The data grows as the product** while the model grows
# only as the sum: adding a hundred food options adds a hundred variables but four hundred numbers to
# look up. In practice the data, not the solve, is the expensive part of scaling this model up.
# :::
# <!-- END PUBLISHED ANSWER -->

# %% [markdown]
# ### 1-D. Classify the problem
#
# Is this an LP, QP, NLP, MILP or MINLP? Justify your classification by referring to the objective,
# the constraints and the variable domains. Is the problem convex? What does that buy you?
#
# <!-- BEGIN PUBLISHED ANSWER -->
# :::{dropdown} Click to check your answer to 1-D
#
# **Linear program (LP).**
#
# * The objective $\sum_i \pi_i x_i$ is **linear** in $x$ --- the prices are data, not variables.
# * Every constraint $\sum_i D_{i,j} x_i \geq r_j$ is **linear** in $x$, for the same reason.
# * Every variable is **continuous** (`NonNegativeReals`), so nothing is integer and it is not a
#   MILP.
#
# **It is convex**, because a linear objective over a polyhedral feasible set is convex. Two things
# follow, and they are the reason we care about the classification at all:
#
# 1. **Every local minimum is a global minimum.** A solver reporting "optimal" has found *the*
#    answer, not *an* answer. Contrast Problems 3 and 4 of this assignment, where the initial guess
#    changes the answer you get.
# 2. **Specialized algorithms apply.** Simplex and interior-point methods exploit linearity directly,
#    and an LP with thousands of variables is routine. HiGHS or GLPK would solve this instantly.
#    [](../1/LP.ipynb) uses Ipopt --- a general nonlinear solver --- only because we want the KKT
#    multipliers it reports. An LP solver can never be used on an NLP; an NLP solver can always be
#    used on an LP, and usually should not be.
# :::
# <!-- END PUBLISHED ANSWER -->

# %% [markdown]
# ### 1-E. Now check your work in Pyomo, and refresh your Pyomo fundamentals
#
# **Only after you have attempted 1-A through 1-D on paper**, open
# [](../1/LP.ipynb) --- *Continuous Optimization: Linear Programming*. It is the same diet problem,
# worked in full.
#
# Use it twice:
#
# 1. **To mark your own work.** Its *Propose an Optimization Model* section gives the sets,
#    parameters, variables, objective, constraints and the degree of freedom analysis, each behind a
#    dropdown. Compare them against what you wrote.
# 2. **To refresh your Pyomo.** Its *Solve in Pyomo* section builds the model step by step ---
#    `pyo.Set`, `pyo.Param`, `pyo.Var`, the `@m.Constraint` decorator, `@m.Objective`, then
#    `SolverFactory` --- and its *Analyze Results* section extracts the solution and the KKT
#    multipliers. Problems 3 and 4 below assume you are fluent with all of that.
#
# Nothing to submit for this part.

# %% [markdown]
# ## Problem 2. Portfolio optimization
#
# *Pencil and paper. Attempt every part before expanding an answer.*
#
# **Background.** You have a fixed amount of money and $N$ assets to put it in. Each asset's return
# fluctuates from day to day. You want to choose what **fraction** of your money goes into each asset
# so that the **variance** of the portfolio's return is as small as possible, while still achieving at
# least a required expected return $\rho$. This is the Markowitz mean/variance model, and it is the
# problem that won Markowitz a Nobel Prize in 1990.
#
# The data are five years of daily adjusted closing prices for $N = 5$ market indices: DJI, GSPC
# (S&P 500), IXIC (NASDAQ Composite), RUT (Russell 2000) and VIX. From 1258 one-day return rates the
# code estimates $\bar{r}$, the average one-day return of each index, and $\Sigma_r$, the $5 \times 5$
# covariance matrix of those returns.
#
# **Instruction.** Consider the following Pyomo code, which should NOT contain any mistakes.
#
# ```python
# def create_portfolio_model(rho, r_avg, cov):
#     # Create the Markowitz mean/variance portfolio model in Pyomo
#     #
#     # Arguments:
#     #     rho: required expected return of the portfolio (float)
#     #     r_avg: average one-day return of each asset (pandas Series)
#     #     cov: covariance matrix of the one-day returns (pandas DataFrame)
#
#     m = pyo.ConcreteModel()
#
#     m.ASSETS = pyo.Set(initialize=list(r_avg.index))
#
#     m.rho = pyo.Param(initialize=rho, mutable=True, units=1 / u.day)
#     m.r_avg = pyo.Param(m.ASSETS, initialize=r_avg.to_dict(), units=1 / u.day)
#     m.cov = pyo.Param(
#         m.ASSETS,
#         m.ASSETS,
#         initialize={(i, j): cov.loc[i, j] for i in m.ASSETS for j in m.ASSETS},
#         units=1 / u.day**2,
#     )
#
#     m.x = pyo.Var(
#         m.ASSETS, domain=pyo.NonNegativeReals, initialize=0.0, units=u.dimensionless
#     )
#
#     @m.Objective(sense=pyo.minimize)
#     def OBJ(b):
#         return sum(b.x[i] * b.cov[i, j] * b.x[j] for i in b.ASSETS for j in b.ASSETS)
#
#     # C1
#     @m.Constraint()
#     def required_return(b):
#         return sum(b.r_avg[i] * b.x[i] for i in b.ASSETS) >= b.rho
#
#     # C2
#     @m.Constraint()
#     def budget(b):
#         return sum(b.x[i] for i in b.ASSETS) == 1
#
#     assert_units_consistent(m)
#
#     return m
# ```
#
# Solving with `rho = 0.0008` per day gives:
#
# ```
# Standard deviation of the return rate = 0.004580 per day
#
# Optimal allocation of funds:
#     DJI   30.62%
#   GSPC   18.51%
#   IXIC   42.93%
#    RUT    0.02%
#    VIX    7.93%
#
# Expected return = 0.000800 per day
# ```

# %% [markdown]
# ### 2-A. Translate the Pyomo code into a mathematical model (symbols and equations) using set notation similar to our in-class examples
#
# Next to each set, parameter, variable, and equation, write a few-word description. After C1 and C2,
# write a brief description. You are filling in the missing Python comments here.
#
# **Sets.**
#
# **Parameters (Data).** *Hint*: state the units of each one, and say which one is `mutable` and why.
#
# **Variables.**
#
# **Objective.** Write it twice: once with explicit sums over the index sets, and once in matrix
# notation.
#
# **Constraints.**
#
# <!-- BEGIN PUBLISHED ANSWER -->
# :::{dropdown} Click to check your answer to 2-A
#
# **Sets.**
#
# $\mathcal{S} = \{\mathrm{DJI}, \mathrm{GSPC}, \mathrm{IXIC}, \mathrm{RUT}, \mathrm{VIX}\}$
# &nbsp;&nbsp; the assets (`m.ASSETS`), $|\mathcal{S}| = N = 5$
#
# **Parameters (Data).**
#
# $\bar{r}_i$ &nbsp; [1/day] &nbsp;&nbsp; average one-day return of asset $i \in \mathcal{S}$
# (`m.r_avg`)
#
# $\Sigma_{i,j}$ &nbsp; [1/day$^2$] &nbsp;&nbsp; covariance of the one-day returns of assets $i$ and
# $j$ (`m.cov`); symmetric, so $\Sigma_{i,j} = \Sigma_{j,i}$
#
# $\rho$ &nbsp; [1/day] &nbsp;&nbsp; required expected return of the portfolio (`m.rho`).
# **Declared `mutable=True`** so that the efficient frontier can be swept by changing $\rho$ and
# re-solving, without rebuilding the model.
#
# Both $\bar{r}$ and $\Sigma_r$ are **estimated from data**, not given. Hold that thought --- the last
# section of the notebook is about what that costs you.
#
# **Variables.**
#
# $x_i$ &nbsp; [dimensionless] &nbsp;&nbsp; fraction of the funds placed in asset $i \in \mathcal{S}$
# (`m.x`)
#
# **Objective.**
#
# $$
# \min_{x} \quad z \; := \; \sum_{i \in \mathcal{S}} \sum_{j \in \mathcal{S}} x_i \, \Sigma_{i,j} \, x_j
# \;\; = \;\; x^T \Sigma_r \, x
# \qquad \text{(variance of the portfolio return, 1/day}^2\text{)}
# $$
#
# **Constraints.**
#
# $$
# \text{C1:} \quad \sum_{i \in \mathcal{S}} \bar{r}_i \, x_i \; \geq \; \rho
# \qquad \Longleftrightarrow \qquad \bar{r}^T x \geq \rho
# $$
#
# *Achieve the required return*: the portfolio's expected one-day return must be at least $\rho$.
#
# $$
# \text{C2:} \quad \sum_{i \in \mathcal{S}} x_i \; = \; 1
# $$
#
# *Invest all of it*: the fractions must sum to one. This is the only **equality** in the model.
#
# $$
# x_i \; \geq \; 0, \qquad \forall \, i \in \mathcal{S}
# $$
#
# *No short selling*: from `domain=pyo.NonNegativeReals`, not from a Pyomo `Constraint`. Dropping it
# would let the model borrow one asset to buy another.
# :::
# <!-- END PUBLISHED ANSWER -->

# %% [markdown]
# ### 2-B. Degree of freedom analysis
#
# Count the variables, equality constraints and inequality constraints separately and report the
# degrees of freedom. Is C1 active at the reported solution? How can you tell from the printed output
# alone?
#
# <!-- BEGIN PUBLISHED ANSWER -->
# :::{dropdown} Click to check your answer to 2-B
#
# | | Count |
# | --- | --- |
# | Continuous variables | 5 &nbsp; ($N = 5$) |
# | Integer/discrete variables | 0 |
# | Equality constraints | 1 &nbsp; (C2, the budget) |
# | Inequality constraints | 1 &nbsp; (C1, the required return) |
# | Variable bounds | 5 &nbsp; ($x_i \geq 0$) |
#
# **Degrees of freedom** $= 5 - 1 = 4$.
#
# **C1 is active.** The printed expected return is $0.000800$ per day, which equals $\rho$ exactly ---
# the model bought no more return than it was told to, because return costs variance. If $\rho$ were
# reduced far enough C1 would go slack and the answer would stop changing: the minimum-variance
# portfolio already returns $0.000678$ per day, so for any $\rho \leq 0.000678$ the model returns the
# same allocation and C1 is inactive. That flat left-hand end of the efficient frontier is a good
# check that you have understood what "active" means.
#
# Note also $x_{\mathrm{RUT}} = 0.02\%$ --- effectively zero. Its bound is *nearly* active. Whether
# you call that active is a numerical judgement, not an algebraic one, and it is exactly the sort of
# thing the dual variables are for.
# :::
# <!-- END PUBLISHED ANSWER -->

# %% [markdown]
# ### 2-C. Problem size
#
# Let $N$ represent the number of assets. Using this symbol, determine the variables and constraints
# in your model. After each header below, give a number with a brief justification.
#
# **Number of continuous variables:**
#
# **Number of integer/discrete variables:**
#
# **Number of equality constraints:**
#
# **Number of inequality constraints:**
#
# **Number of parameters (data values) you must supply:**
#
# Finally: compare how this model scales with how the diet model in Problem 1 scales. They are not
# the same, and the difference is the interesting part.
#
# <!-- BEGIN PUBLISHED ANSWER -->
# :::{dropdown} Click to check your answer to 2-C
#
# **Continuous variables: $N$.** One fraction $x_i$ per asset.
#
# **Integer/discrete variables: 0.** You may hold any fraction of an asset in this model. (A real
# portfolio has a minimum lot size, and adding that turns this into an MINLP --- a much harder
# problem.)
#
# **Equality constraints: 1.** C2, the budget. It does **not** grow with $N$.
#
# **Inequality constraints: 1** (C1), **plus $N$ variable bounds** $x_i \geq 0$. C1 does not grow with
# $N$ either.
#
# **Parameters: $N^2 + N + 1$.** The covariance matrix $\Sigma_r$ alone is $N \times N$, plus $N$
# mean returns and the scalar $\rho$. Exploiting symmetry, $\Sigma_r$ has $N(N+1)/2$ distinct entries.
#
# **How the two models scale differently.**
#
# | | Diet (Problem 1) | Portfolio (Problem 2) |
# | --- | --- | --- |
# | Variables | $N_f$ | $N$ |
# | Constraints (excluding bounds) | $N_n$ --- grows | $2$ --- **constant** |
# | Data values | $N_f N_n + N_f + N_n$ | $N^2 + N + 1$ |
#
# The portfolio model's *constraint* count never grows: adding assets adds variables and data but not
# rows. Its difficulty grows through the **objective**, whose $N \times N$ Hessian is dense. The diet
# model's difficulty grows through the constraint matrix instead. "How big is the problem" is not one
# number, and which number matters depends on the algorithm.
#
# There is also a statistical cost hiding in $N^2$: you must *estimate* $N(N+1)/2$ covariances from
# the same 1258 days of data no matter how large $N$ is. Doubling the assets quadruples the
# parameters you are estimating from a fixed amount of data.
# :::
# <!-- END PUBLISHED ANSWER -->

# %% [markdown]
# ### 2-D. Classify the problem
#
# Is this an LP, QP, NLP, MILP or MINLP? Justify your classification. Where, exactly, is the
# nonlinearity, and what does it cost you?
#
# <!-- BEGIN PUBLISHED ANSWER -->
# :::{dropdown} Click to check your answer to 2-D
#
# **Quadratic program (QP).** The objective $x^T \Sigma_r x$ is **quadratic** in $x$; both constraints
# are **linear** in $x$; all variables are **continuous**.
#
# **The nonlinearity is entirely in the objective.** The feasible set is a polyhedron --- a hyperplane
# $\sum_i x_i = 1$ intersected with the half-spaces $\bar{r}^T x \geq \rho$ and $x_i \geq 0$ --- so
# the *geometry* is as simple as a linear program's.
#
# **What it costs you** is that the optimum need not sit at a vertex. In an LP you can always find an
# optimal vertex, which is what makes simplex work. Here the minimum can sit anywhere in the feasible
# set --- on a face, on an edge, or in the interior --- so vertex enumeration is useless and you need
# the general algorithms from the second half of this course.
#
# **It is still convex.** $\Sigma_r$ is a covariance matrix, hence symmetric positive *semi*definite,
# so the objective is convex; the feasible set is convex. Every local minimum is therefore global. A
# QP is only a mildly harder problem than an LP; a *non-convex* QP is a genuinely hard one.
# :::
# <!-- END PUBLISHED ANSWER -->

# %% [markdown]
# ### 2-E. The Hessian of the objective
#
# In this part we explore the Hessian $\nabla_{xx} z$ of the portfolio variance. The Hessian is what
# determines whether the problem is convex, and how hard it is to solve numerically.
#
# 1. Starting from $z = \sum_{i \in \mathcal{S}} \sum_{j \in \mathcal{S}} x_i \Sigma_{i,j} x_j$,
#    compute $\partial z / \partial x_k$ and then $\partial^2 z / \partial x_k \partial x_l$. Use the
#    symmetry of $\Sigma_r$ to simplify. Show that $\nabla_{xx} z = 2 \Sigma_r$.
# 2. State the condition on the eigenvalues of $\Sigma_r$ under which the problem is convex, and
#    explain in one or two sentences why a covariance matrix always satisfies it.
# 3. The eigenvalues of $\Sigma_r$ for the five indices above are
#    $9.59 \times 10^{-7}$, $8.14 \times 10^{-6}$, $1.71 \times 10^{-5}$, $1.02 \times 10^{-4}$ and
#    $7.55 \times 10^{-3}$. Interpret the smallest one. What does it say about the portfolio, and
#    what does it say about the numerics?
#
# <!-- BEGIN PUBLISHED ANSWER -->
# :::{dropdown} Click to check your answer to 2-E
#
# **1. The Hessian.** Write $z = \sum_i \sum_j x_i \Sigma_{i,j} x_j$. Differentiating with respect to
# $x_k$, the index $k$ can appear in either factor:
#
# $$
# \frac{\partial z}{\partial x_k}
# = \sum_{j} \Sigma_{k,j} x_j + \sum_{i} x_i \Sigma_{i,k}
# = 2 \sum_{j} \Sigma_{k,j} x_j
# $$
#
# where the last step uses $\Sigma_{i,k} = \Sigma_{k,i}$. Differentiating again,
#
# $$
# \frac{\partial^2 z}{\partial x_k \, \partial x_l} = 2 \Sigma_{k,l}
# \qquad \Longrightarrow \qquad \nabla_{xx} z = 2 \Sigma_r .
# $$
#
# The Hessian is **constant** --- independent of $x$ --- which is the defining feature of a quadratic
# objective, and the reason a QP is so much easier than a general NLP.
#
# **2. Convexity.** The problem is convex if and only if $\nabla_{xx} z = 2\Sigma_r$ is positive
# semidefinite, i.e. **every eigenvalue of $\Sigma_r$ is $\geq 0$**. A covariance matrix always is:
# for any vector $v$, $v^T \Sigma_r v$ is the variance of the scalar random variable $v^T r$, and a
# variance cannot be negative. So the Markowitz model is convex *by construction*, whatever the data.
#
# **3. The smallest eigenvalue.** All five eigenvalues are strictly positive, so $\Sigma_r$ is
# positive *definite* here and the minimizer is unique.
#
# *What it says about the portfolio.* Let $v_1$ be the eigenvector for
# $\lambda_1 = 9.59 \times 10^{-7}$. Moving the allocation along $v_1$ changes the portfolio variance
# by almost nothing: $v_1$ is a combination of indices that move together so tightly that swapping
# between them is nearly free in risk terms. DJI, GSPC and RUT are all broad US equity indices, so
# this is exactly what you would expect. The optimizer is nearly indifferent along that direction ---
# which means the "optimal" split between those indices is not a meaningful recommendation.
#
# *What it says about the numerics.* The condition number is
# $7.55 \times 10^{-3} / 9.59 \times 10^{-7} \approx 7900$. The objective is a long, thin valley: steep
# across $v_5$, almost flat along $v_1$. Steepest descent would zig-zag badly; Newton-type methods
# handle it because they rescale by the Hessian. This is the same near-zero-eigenvalue picture as
# parameter estimability in nonlinear regression --- a flat direction means the data do not determine
# that combination of decisions.
# :::
# <!-- END PUBLISHED ANSWER -->

# %% [markdown]
# ### 2-F. Check your work
#
# **Only after you have attempted 2-A through 2-E on paper**, open
# [](../1/Portfolio-Optimization.ipynb). It works the same model in full, sweeps $\rho$ to trace the
# efficient frontier, and closes with a section on how much the estimated $\bar{r}$ can be trusted.
#
# Nothing to submit for this part.

# %% [markdown]
# Problems 3 and 4 below are adapted from the Pyomo team's excellent PyomoFest workshop
# (Bynum et al., 2021). Special thanks to them for creating these exercises.

# %% [markdown]
# ## Problem 3. Nonlinear programs: initialization and problem formulation are very important!

# %% [markdown]
# ### Alternative initialization
#
# Effective initialization can be critical for solving nonlinear problems, since they can have several local solutions and numerical difficulties. Solve the [Rosenbrock problem](https://en.wikipedia.org/wiki/Rosenbrock_function) using different initial values for the x (and optionally y) variable(s). Write a loop that varies the initial value from 2.0 to 6.0, solves the problem, and prints the solution for each iteration of the loop.

# %%
model = pyo.ConcreteModel()
model.x = pyo.Var()
model.y = pyo.Var()


def rosenbrock(m):
    return (1.0 - m.x) ** 2 + 10000.0 * (m.y - m.x**2) ** 2


model.obj = pyo.Objective(rule=rosenbrock, sense=pyo.minimize)


solver = pyo.SolverFactory("ipopt")

print("x_init, y_init, x_soln, y_soln")

# Add your solution here

# %% [markdown]
# As elaborated here, the [Rosenbrock problem](https://en.wikipedia.org/wiki/Rosenbrock_function) is a classic "hard" test case for optimization algorithms. Your results may surprise you (and show the effectiveness of Pyomo and Ipopt!).

# %% [markdown]
# ### Evaluation errors
#
# Consider the following problem with **initial values** $x$=5, $y$=5.
#
# $\min_{x,y} f(x,y)=(x-1.01)^2+y^2$
#
# s.t. $y=\sqrt{x-1.0}$

# %% [markdown]
# 1. Formulate this Pyomo model and solve using IPOPT. You should get a list of errors from the solver. Add the IPOPT solver option solver.options['halt_on_ampl_error']='yes' to find the problem. *Hint*: the error output might be ordered strangely, look this up in the console output. What did you discover? How might you fix this?

# %%
# Add your solution here

# %% [markdown]
# **Question Answers**
#
# *Fill in here*

# %% [markdown]
# 2. Add bounds $x \geq 1$ to fix this problem and resolve. Comment on the number of iterations and the quality of solution. Note, the problem still occurs because $x \geq 1$ is not enforced exactly, and small numerical values still cause the error.

# %%
# Add your solution here

# %% [markdown]
# **Discussion**
#
# *Fill in here*

# %% [markdown]
# 3. Think about other solutions for this problem and attempt to implement one of these solutions. *Hint*: $x \geq 1.001$.

# %%
model = pyo.ConcreteModel()

model.x = pyo.Var(initialize=5.0, bounds=(1.001, None))
model.y = pyo.Var(initialize=5.0)


def obj_rule(m):
    return (m.x - 1.01) ** 2 + m.y**2


model.obj = pyo.Objective(rule=obj_rule)


def con_rule(m):
    return m.y == pyo.sqrt(m.x - 1.0)


model.con = pyo.Constraint(rule=con_rule)

solver = pyo.SolverFactory("ipopt")
solver.options["halt_on_ampl_error"] = "yes"
results = solver.solve(model, tee=True)
assert pyo.check_optimal_termination(results), (
    f"Solve failed: status={results.solver.status}, "
    f"termination={results.solver.termination_condition}"
)

print(pyo.value(model.x))
print(pyo.value(model.y))

# %% [markdown]
# ### Alternative formulations
#
# Consider the following problem with initial values $x$=5, $y$=5.
#
# $\min_{x,y} f(x,y)=(x-1.01)^2+y^2$
#
# s.t. $\frac{x-1}{y}=1$
#
# Note, the solution to this problem is $x$=1.005 and $y$=0.005. There are several ways that the problem above can be reformulated. Some examples are shown below. Which ones do you expect to be better? Why?
#
# 1. $\min_{x,y} f(x,y)=(x-1.01)^2+y^2$
#
# s.t. $\frac{x-1}{y}=1$
#
# 2. $\min_{x,y} f(x,y)=(x-1.01)^2+y^2$
#
# s.t. $\frac{x}{y+1}=1$
#
# 3. $\min_{x,y} f(x,y)=(x-1.01)^2+y^2$
#
# s.t. $y=x-1$
#
# Implement Pyomo models for each formulation and solve with IPOPT.

# %% [markdown]
# #### Formulation 1

# %%
# Add your solution here

# %% [markdown]
# #### Formulation 2

# %%
# Add your solution here

# %% [markdown]
# #### Formulation 3

# %%
# Add your solution here

# %% [markdown]
# Note the number of iterations and quality of solutions. What can you learn about the problem formulation from these examples?
#
# **Discussion**
#
# *Fill in here*

# %% [markdown]
# Bounds and initialization can be very helpful when solving nonlinear optimization problems. Resolve the original problem below, but add bounds, $y \geq 0$. Note the number of iterations and quality of solution, and compare with what you found for Formulation 1.

# %%
# Add your solution here

# %% [markdown]
# **Discussion**
#
# *Fill in here*

# %% [markdown]
# ## Problem 4. Reactor design (Bynum et al., 2021; Bequette, 2003)
#
# Here we will consider a chemical reactor designed to produce product B from reactant A using a reaction scheme known as the Van de Vusse reaction:
#
# $A \overset{k_1}{\rightarrow} B \overset{k_2}{\rightarrow} C$
#
# $2A \overset{k_3}{\rightarrow} D$
#
# Under appropriate assumptions, $F$ is the volumetric flowrate through the tank. The concentration of component A in the feed is $c_{Af}$, and the concentrations in the reactor are equivalent to the concentrations of each component
# flowing out of the reactor, given by $c_A$, $c_B$, $c_C$, and $c_D$.
#
# If the reactor is too small, we will not produce sufficient quantity of B, and if the reactor is too large, much of B will be further reacted to form the undesired product C. Therefore, our goal is to solve for the reactor volume that maximizes the outlet concentration for product B.
#
# The steady-state mole balances for each of the four components are given by
#
# $0=\frac{F}{V}c_{Af}-\frac{F}{V}c_A-k_1c_A-2k_3c^2_A$
#
# $0=-\frac{F}{V}c_{B}+k_1c_A-k_2c_B$
#
# $0=-\frac{F}{V}c_{C}+k_2c_B$
#
# $0=-\frac{F}{V}c_{D}+k_3c^2_A$
#
# The known parameters for the system are:
#
# $c_{Af}=10000\frac{\mathrm{gmol}}{\mathrm{m}^3}$
#
# $k_1=\frac{5}{6}\mathrm{min}^{-1}$
#
# $k_2=\frac{5}{3}\mathrm{min}^{-1}$
#
# $k_3=\frac{1}{6000}\frac{\mathrm{m}^3}{\mathrm{gmol}~\mathrm{min}}$
#
# Formulate and solve this optimization problem using Pyomo. Since the volumetric flowrate $F$ always appears as the numerator over the reactor volume $V$, it is common to consider this ratio as a single variable, called the space-velocity $SV$.
#
# **References**:
# Bynum, M. L., Hackebeil, G. A., Hart, W. E., Laird, C. D., Nicholson, B. L., Siirola, J. D., Watson, J.-P., and Woodruff, D. L. *Pyomo — Optimization Modeling in Python*, Third Edition. Springer Optimization and Its Applications, Vol. 67, 2021. (§7.4.4, p. 106)
#
# B.W. Bequette. Process control: modeling, design, and simulation. Prentice Hall, 2003.

# %%
# Add your solution here
